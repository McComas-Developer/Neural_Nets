# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#Problem One

# %% [markdown]
# $\zeta(x) = {\log(1+e^x)}$

# %% [markdown]
# $\sigma(x) = \frac{1}{1+e^{-x}}$

# %% [markdown]
# $y_i = \frac{e^{y_i}}{{\sum_{j=1}^N}e^{y_j}}$

# %%
# Problem 2
x = np.asarray(range(-5, 6))
y = 1/(1+np.exp(-x))
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y)
plt.show()

# %%
# Problem 3
from sympy import *
init_printing(use_latex=True)

# %%
x

# %%
x = symbols('x')
y = 1/(1+exp(-x))
dydx = y.diff(x)
plot(dydx, xlim=(-5, 5))
